# %% [markdown]
# <a href="https://colab.research.google.com/github/RoniDM011/DClab/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is a single-line comment
print("Hello! Let's learn Python fundamentals!")
"""
This is a
multi-line comment
(also called docstring)
"""
# Out:
# Hello! Let's learn Python fundamentals!
# '\nThis is a\nmulti-line comment\n(also called docstring)\n'

# %%
print("\n" + "="*50)
print("VARIABLES AND DATA TYPES")
print("="*50)
# Out:
# ==================================================
# VARIABLES AND DATA TYPES
# ==================================================

# %%
age = 25                    # Integer (int)
price = 19.99              # Float (float)
complex_num = 3 + 4j       # Complex number

name = "Alice"             # String (str)
message = 'Python is fun!' # String with single quotes

is_student = True          # Boolean (bool)
has_job = False

print(f"Name: {name} (Type: {type(name)})")
print(f"Age: {age} (Type: {type(age)})")
print(f"Price: ${price} (Type: {type(price)})")
print(f"Student?: {is_student} (Type: {type(is_student)})")
# Out:
# Name: Alice (Type: <class 'str'>)
# Age: 25 (Type: <class 'int'>)
# Price: $19.99 (Type: <class 'float'>)
# Student?: True (Type: <class 'bool'>)

# %%
# String to Integer
num_str = "100"
num_int = int(num_str)
print(f'Converting "{num_str}" to integer: {num_int}')

# Integer to Float
num_float = float(age)
print(f"Converting {age} to float: {num_float}")

# Number to String
age_str = str(age)
print(f"Converting {age} to string: '{age_str}'")

# Float to Integer (truncates decimal)
pi = 3.14159
pi_int = int(pi)
print(f"Converting {pi} to integer: {pi_int}")
# Out:
# Converting "100" to integer: 100
# Converting 25 to float: 25.0
# Converting 25 to string: '25'
# Converting 3.14159 to integer: 3

# %%
# ---------- 4. STRING OPERATIONS ----------
print("\n" + "="*50)
print("STRING OPERATIONS")
print("="*50)

greeting = "Hello"
name = "Bob"

# String concatenation
combined = greeting + " " + name
print(f"Concatenation: {combined}")

# String repetition
laugh = "Ha" * 3
print(f"Repetition: {laugh}")

# String methods
text = "  Python Programming  "
print(f"Original: '{text}'")
print(f"Strip whitespace: '{text.strip()}'")
print(f"Uppercase: {text.upper()}")
print(f"Lowercase: {text.lower()}")
print(f"Replace: {text.replace('Python', 'Java')}")
print(f"Split: {text.split()}")

# String formatting (f-strings)
name = "Charlie"
score = 95
print(f"Student: {name}, Score: {score}")

# String slicing
word = "Programming"
print(f"Word: {word}")
print(f"First 3 chars: {word[:3]}")
print(f"Last 3 chars: {word[-3:]}")
print(f"Reverse: {word[::-1]}")
print(f"Reverse: {word[3:11:1]}{word[:3:1]}")
# Out:
# ==================================================
# STRING OPERATIONS
# ==================================================
# Concatenation: Hello Bob
# Repetition: HaHaHa
# Original: '  Python Programming  '
# Strip whitespace: 'Python Programming'
# Uppercase:   PYTHON PROGRAMMING
# Lowercase:   python programming
# Replace:   Java Programming
# Split: ['Python', 'Programming']
# Student: Charlie, Score: 95
# Word: Programming
# First 3 chars: Pro
# Last 3 chars: ing
# Reverse: gnimmargorP
# Reverse: grammingPro

# %%
# ---------- 5. BASIC OPERATORS ----------
print("\n" + "="*50)
print("BASIC OPERATORS")
print("="*50)

a = 10
b = 3

# Arithmetic operators
print(f"a = {a}, b = {b}")
print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
print(f"Floor Division: {a} // {b} = {a // b}")
print(f"Modulus: {a} % {b} = {a % b}")
print(f"Exponent: {a} ** {b} = {a ** b}")

# Comparison operators
print(f"\nComparison Operators:")
print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
print(f"{a} >= {b}: {a >= b}")
print(f"{a} <= {b}: {a <= b}")

# Logical operators
print(f"\nLogical Operators:")
x = True
y = False
print(f"x = {x}, y = {y}")
print(f"x and y: {x and y}")
print(f"x or y: {x or y}")
print(f"not x: {not x}")
# Out:
# ==================================================
# BASIC OPERATORS
# ==================================================
# a = 10, b = 3
# Addition: 10 + 3 = 13
# Subtraction: 10 - 3 = 7
# Multiplication: 10 * 3 = 30
# Division: 10 / 3 = 3.3333333333333335
# Floor Division: 10 // 3 = 3
# Modulus: 10 % 3 = 1
# Exponent: 10 ** 3 = 1000
#
# Comparison Operators:
# 10 == 3: False
# 10 != 3: True
# 10 > 3: True
# 10 < 3: False
# 10 >= 3: True
# 10 <= 3: False
#
# Logical Operators:
# x = True, y = False
# x and y: False
# x or y: True
# not x: False

# %%
# ---------- 6. GETTING USER INPUT ----------
print("\n" + "="*50)
print("USER INPUT")
print("="*50)

# In Colab, you can use input() - it will prompt in the cell output
name = input("Enter your name: ")
age = input("Enter your age: ")

print(f"\nHello {name}! You are {age} years old.")
print(f"In 5 years, you will be {int(age) + 5} years old!")
# Out:
# ==================================================
# USER INPUT
# ==================================================
# Enter your name: Ronish
# Enter your age: 21
#
# Hello Ronish! You are 21 years old.
# In 5 years, you will be 26 years old!

# %%
# ---------- 7. CONDITIONAL STATEMENTS ----------
print("\n" + "="*50)
print("CONDITIONAL STATEMENTS (if-elif-else)")
print("="*50)

# Example 1: Simple if
temperature = 25
print(f"Temperature: {temperature}°C")

if temperature > 30:
    print("It's hot outside! 🥵")
elif temperature > 20:
    print("It's warm outside! 😊")
elif temperature > 10:
    print("It's cool outside! 🧥")
else:
    print("It's cold outside! 🥶")

# Example 2: Nested conditions
age = 18
has_license = True

if age >= 18:
    if has_license:
        print("You can drive a car! 🚗")
    else:
        print("You're old enough but need a license first!")
else:
    print("You're too young to drive!")
# Out:
# ==================================================
# CONDITIONAL STATEMENTS (if-elif-else)
# ==================================================
# Temperature: 25°C
# It's warm outside! 😊
# You can drive a car! 🚗

# %%
# ---------- 8. LOOPS ----------
print("\n" + "="*50)
print("LOOPS")
print("="*50)

# FOR loop - iterating over a range
print("For loop - Counting 1 to 5:")
for i in range(1, 6):
    print(f"Count: {i}")

# FOR loop - iterating over a list
print("\nFor loop - Iterating through fruits:")
fruits = ["apple", "banana", "orange", "grape"]
for fruit in fruits:
    print(f"I like {fruit}")

# FOR loop - iterating over a string
print("\nFor loop - Iterating through characters:")
word = "Python"
for letter in word:
    print(f"Letter: {letter}")

# WHILE loop
print("\nWhile loop - Countdown:")
count = 5
while count > 0:
    print(f"Countdown: {count}")
    count -= 1  # Decrease count by 1
print("Blast off! 🚀")

# Break and continue
print("\nBreak and Continue Example:")
for num in range(1, 11):
    if num == 5:
        continue  # Skip 5
    if num == 8:
        break     # Stop at 8
    print(f"Number: {num}")
# Out:
# ==================================================
# LOOPS
# ==================================================
# For loop - Counting 1 to 5:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5
#
# For loop - Iterating through fruits:
# I like apple
# I like banana
# I like orange
# I like grape
#
# For loop - Iterating through characters:
# Letter: P
# Letter: y
# Letter: t
# Letter: h
# Letter: o
# Letter: n
#
# While loop - Countdown:
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Blast off! 🚀
#
# Break and Continue Example:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 6
# Number: 7

# %%
# ---------- 9. LISTS (Arrays) ----------
print("\n" + "="*50)
print("LISTS")
print("="*50)

# Creating lists
numbers = [1, 2, 3, 4, 5]
mixed = [1, "hello", 3.14, True]
colors = ["red", "green", "blue"]

print(f"Numbers: {numbers}")
print(f"Mixed list: {mixed}")
print(f"Colors: {colors}")

# Accessing elements
print(f"\nFirst color: {colors[0]}")
print(f"Last color: {colors[-1]}")

# List operations
colors.append("yellow")     # Add to end
print(f"After append: {colors}")

colors.insert(1, "orange")  # Insert at position
print(f"After insert: {colors}")

colors.remove("green")       # Remove element
print(f"After remove: {colors}")

# Slicing lists
print(f"\nFirst 2 colors: {colors[:2]}")
print(f"Last 2 colors: {colors[-2:]}")

# List comprehension
squares = [x**2 for x in range(1, 6)]
print(f"\nSquares: {squares}")
# Out:
# ==================================================
# LISTS
# ==================================================
# Numbers: [1, 2, 3, 4, 5]
# Mixed list: [1, 'hello', 3.14, True]
# Colors: ['red', 'green', 'blue']
#
# First color: red
# Last color: blue
# After append: ['red', 'green', 'blue', 'yellow']
# After insert: ['red', 'orange', 'green', 'blue', 'yellow']
# After remove: ['red', 'orange', 'blue', 'yellow']
#
# First 2 colors: ['red', 'orange']
# Last 2 colors: ['blue', 'yellow']
#
# Squares: [1, 4, 9, 16, 25]

# %%
# ---------- 10. DICTIONARIES ----------
print("\n" + "="*50)
print("DICTIONARIES (Key-Value Pairs)")
print("="*50)

# Creating a dictionary
person = {
    "name": "John",
    "age": 30,
    "city": "New York",
    "is_student": False
}

print(f"Person dictionary: {person}")

# Accessing values
print(f"\nName: {person['name']}")
print(f"Age: {person.get('age')}")

# Modifying dictionary
person["age"] = 31
person["job"] = "Engineer"
print(f"\nUpdated person: {person}")

# Iterating through dictionary
print("\nIterating through dictionary:")
for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# ==================================================
# DICTIONARIES (Key-Value Pairs)
# ==================================================
# Person dictionary: {'name': 'John', 'age': 30, 'city': 'New York', 'is_student': False}
#
# Name: John
# Age: 30
#
# Updated person: {'name': 'John', 'age': 31, 'city': 'New York', 'is_student': False, 'job': 'Engineer'}
#
# Iterating through dictionary:
# name: John
# age: 31
# city: New York
# is_student: False
# job: Engineer

# %%
# ---------- 11. FUNCTIONS ----------
print("\n" + "="*50)
print("FUNCTIONS")
print("="*50)

# Simple function
def greet():
    print("Hello! Welcome to Python!")

# Function with parameters
def greet_person(name):
    print(f"Hello, {name}!")

# Function with return value
def add_numbers(a, b):
    return a + b

# Function with default parameter
def multiply(a, b=2):
    return a * b

# Calling functions
greet()
greet_person("Alice")

sum_result = add_numbers(5, 3)
print(f"5 + 3 = {sum_result}")

product = multiply(5)      # Uses default b=2
print(f"5 * 2 = {product}")

product2 = multiply(5, 4)  # Overrides default
print(f"5 * 4 = {product2}")
# Out:
# ==================================================
# FUNCTIONS
# ==================================================
# Hello! Welcome to Python!
# Hello, Alice!
# 5 + 3 = 8
# 5 * 2 = 10
# 5 * 4 = 20

# %%
# ---------- 12. EXCEPTION HANDLING ----------
print("\n" + "="*50)
print("EXCEPTION HANDLING (Error Handling)")
print("="*50)

# Handling division by zero
def safe_divide(a, b):
    try:
        result = a / b
        return result
    except ZeroDivisionError:
        return "Cannot divide by zero!"
    except Exception as e:
        return f"An error occurred: {e}"

print(f"10 / 2 = {safe_divide(10, 2)}")
print(f"10 / 0 = {safe_divide(10, 0)}")

# Handling invalid input
def get_number():
    try:
        num = int(input("Enter a number: "))
        print(f"You entered: {num}")
    except ValueError:
        print("That's not a valid number!")
get_number()
# Out:
# ==================================================
# EXCEPTION HANDLING (Error Handling)
# ==================================================
# 10 / 2 = 5.0
# 10 / 0 = Cannot divide by zero!
# Enter a number: 10
# You entered: 10

# %%
# ---------- 13. PRACTICE EXAMPLES ----------
print("\n" + "="*50)
print("PRACTICE EXAMPLES")
print("="*50)

# Example 1: Even or Odd checker
def check_even_odd():
    num = int(input("\nEnter a number to check if it's even or odd: "))
    if num % 2 == 0:
        print(f"{num} is EVEN")
    else:
        print(f"{num} is ODD")
check_even_odd()

# Example 2: Sum of numbers in a list
def sum_list(numbers):
    total = 0
    for num in numbers:
        total += num
    return total

my_numbers = [10, 20, 30, 40, 50]
print(f"\nList: {my_numbers}")
print(f"Sum of list: {sum_list(my_numbers)}")

# Example 3: Factorial calculator
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
print("\n")
print(f"Factorial of 5: {factorial(5)}")
print(f"Factorial of 7: {factorial(7)}")

# Example 4: Simple calculator
def calculator():
    print("\n--- Simple Calculator ---")
    print("Operations: +, -, *, /")

    num1 = float(input("Enter first number: "))
    op = input("Enter operation (+, -, *, /): ")
    num2 = float(input("Enter second number: "))

    if op == '+':
        result = num1 + num2
    elif op == '-':
        result = num1 - num2
    elif op == '*':
        result = num1 * num2
    elif op == '/':
        if num2 != 0:
            result = num1 / num2
        else:
            result = "Error: Division by zero!"
    else:
        result = "Invalid operation!"

    print(f"Result: {result}")

calculator()
# Out:
# ==================================================
# PRACTICE EXAMPLES
# ==================================================
#
# Enter a number to check if it's even or odd: 11
# 11 is ODD
#
# List: [10, 20, 30, 40, 50]
# Sum of list: 150
#
#
# Factorial of 5: 120
# Factorial of 7: 5040
#
# --- Simple Calculator ---
# Operations: +, -, *, /
# Enter first number: 10
# Enter operation (+, -, *, /): *
# Enter second number: 11
# Result: 110.0

# %%
name = input("Enter your name: ")
age_str = input("Enter your age: ")


age = int(age_str)
current_year = 2026
dob = current_year - age

fav_colors = []
print("Enter three favorite colors:")
for i in range(3):
    clr = input(f"Color {i+1}: ")
    fav_colors.append(clr)

print(f"\nHello, {name}! You were born in {dob}.")
print(f"Your favorite colors are: {', '.join(fav_colors)}.")
# Out:
# Enter your name: ronish
# Enter your age: 22
# Enter three favorite colors:
# Color 1: red
# Color 2: blue
# Color 3: black
#
# Hello, ronish! You were born in 2004.
# Your favorite colors are: red, blue, black.
